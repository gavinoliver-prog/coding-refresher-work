# %% [markdown]
# # Notebook 4 — Bioinformatics Data Science with pandas
# Goal: Learn how to analyze biological datasets using DataFrames.

# %% [markdown]
# ## Section 1 — Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Section 2 — Create a Mutation Dataset

# %%
data = {
    "patient": ["P1","P2","P3","P4","P5"],
    "gene": ["TP53","KRAS","TP53","BRAF","KRAS"],
    "mutation": ["R273H","G12D","R175H","V600E","G12V"]
}

df = pd.DataFrame(data)
df

# %% [markdown]
# ### Exercises
# 1. Print the dataset
# 2. Print the first 3 rows

# %% [markdown]
# ## Section 3 — Working with Columns

# %%
df["gene"]

# %% [markdown]
# ### Exercises
# 3. Print the mutation column
# 4. Print patient and gene columns

# %% [markdown]
# ## Section 4 — Filtering Data

# %%
df[df["gene"] == "KRAS"]

# %% [markdown]
# ### Exercises
# 5. Find TP53 mutations
# 6. Find rows where gene is BRAF

# %% [markdown]
# ## Section 5 — Counting Mutations

# %%
df["gene"].value_counts()

# %% [markdown]
# ### Exercises
# 7. Count mutations per gene
# 8. Count mutations per patient

# %% [markdown]
# ## Section 6 — GroupBy Analysis

# %%
df.groupby("gene").size()

# %% [markdown]
# ### Exercises
# 9. Group by gene
# 10. Group by patient

# %% [markdown]
# ## Section 7 — Adding Computed Columns

# %%
df["gene_length"] = df["gene"].apply(len)
df

# %% [markdown]
# ### Exercises
# 11. Add a column with mutation string length

# %% [markdown]
# ## Section 8 — Plot Mutation Frequencies

# %%
counts = df["gene"].value_counts()
counts.plot(kind="bar")
plt.show()

# %% [markdown]
# ### Exercises
# 12. Plot mutation counts per patient

# %% [markdown]
# ## Section 9 — Reading Data from CSV

# %%
df.to_csv("mutations.csv", index=False)

df2 = pd.read_csv("mutations.csv")
df2

# %% [markdown]
# ### Exercises
# 13. Load a CSV file
# 14. Inspect the first rows

# %% [markdown]
# ## Section 10 — Mini Project
# Build a small analysis that:
# 1. Loads mutation data
# 2. Counts mutations per gene
# 3. Plots mutation frequency

# %% [markdown]
# Exercises 15–25: Build the workflow step-by-step.
